# %% [raw]
# # Welcome to CodeBook – Your Data Science Internship Begins!
# Introduction
# Congratulations! You have just been hired as a Data Scientist Intern at CodeBook – The Social Media for Coders. This Delhi-based company is offering you a ₹10 LPA job if you successfully complete this 1-month internship. But before you get there, you must prove your skills using only Python—no pandas, NumPy, or fancy libraries!
#
# Your manager Puneet Kumar has assigned you your first task: analyzing a data dump of CodeBook users using pure Python. Your job is to load and explore the data to understand its structure.

# %%
import json

# Step 1: Define your data as a Python dict
data = {
    "users": [
        {"id": 1, "name": "Amit", "friends": [2, 3], "liked_pages": [101]},
        {"id": 2, "name": "Priya", "friends": [1, 4], "liked_pages": [102]},
        {"id": 3, "name": "Rahul", "friends": [1], "liked_pages": [101, 103]},
        {"id": 4, "name": "Sara", "friends": [2], "liked_pages": [104]}
    ],
    "pages": [
        {"id": 101, "name": "Python Developers"},
        {"id": 102, "name": "Data Science Enthusiasts"},
        {"id": 103, "name": "AI & ML Community"},
        {"id": 104, "name": "Web Dev Hub"}
    ]
}

# Step 2: Write the data to a JSON file
with open("social_data.json", "w") as json_file:
    json.dump(data, json_file, indent=4)

# %% [markdown]
# # lets move to load data

# %%
def load_data(filename):
    with open(filename, "r") as file:
        data = json.load(file)
        return data

# %%
data = load_data("social_data.json")
data
# Out:
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]},
#   {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]},
#   {'id': 3, 'name': 'Rahul', 'friends': [1], 'liked_pages': [101, 103]},
#   {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]}],
#  'pages': [{'id': 101, 'name': 'Python Developers'},
#   {'id': 102, 'name': 'Data Science Enthusiasts'},
#   {'id': 103, 'name': 'AI & ML Community'},
#   {'id': 104, 'name': 'Web Dev Hub'}]}

# %%
type(data)
# Out:
# dict

# %%
data['users']
# Out:
# [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]},
#  {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]},
#  {'id': 3, 'name': 'Rahul', 'friends': [1], 'liked_pages': [101, 103]},
#  {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]}]

# %%
def getInformation(data):
    print("Users and their Connection\n")
    for user in data['users']:
        print(f"ID: {user['id']}-> {user['name']} is friends with IDs {user['friends']}, likes the pages {user['liked_pages']}")

    print("\nThe Pages They Likes\n")
    for page in data['pages']:
        print(f"ID: {page['id']}-> has an interest in {page['name']}")
    print("\nThat The summarization of connection and behaviour.")

# %%
Relation = getInformation(data)
# Out:
# Users and their Connection
#
# ID: 1-> Amit is friends with IDs [2, 3], likes the pages [101]
# ID: 2-> Priya is friends with IDs [1, 4], likes the pages [102]
# ID: 3-> Rahul is friends with IDs [1], likes the pages [101, 103]
# ID: 4-> Sara is friends with IDs [2], likes the pages [104]
#
# The Pages They Likes
#
# ID: 101-> has an interest in Python Developers
# ID: 102-> has an interest in Data Science Enthusiasts
# ID: 103-> has an interest in AI & ML Community
# ID: 104-> has an interest in Web Dev Hub
#
# That The summarization of connection and behaviour.

# %%
t = data['users']
t
# Out:
# [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]},
#  {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]},
#  {'id': 3, 'name': 'Rahul', 'friends': [1], 'liked_pages': [101, 103]},
#  {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]}]

# %%
for t in data['users']:
    y = t['liked_pages']
    print(y)
# Out:
# [101]
# [102]
# [101, 103]
# [104]
